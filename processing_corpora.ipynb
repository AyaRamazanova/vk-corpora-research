# %%
import json
import pandas as pd
import mining
import statistics

# %%
group_data = mining.load_posts('login', 'password')
with open('group_data.json', 'w') as f:
    json.dump(group_data, f)
# Out:
# getting wall of "overhear", group 0 of 100
# getting wall of "podslushanoklubromantiki", group 1 of 100
# getting wall of "secret_32", group 2 of 100
# getting wall of "podslushanoperm", group 3 of 100
# getting wall of "overstory163", group 4 of 100
# getting wall of "yarchat", group 5 of 100
# getting wall of "podslushanokovrov1", group 6 of 100
# getting wall of "in_yalta", group 7 of 100
# getting wall of "sluhvl", group 8 of 100
# getting wall of "buzpb", group 9 of 100
# getting wall of "ovhdzr", group 10 of 100
# getting wall of "beloretsk3", group 11 of 100
# getting wall of "showvk", group 12 of 100
# getting wall of "pravda.show.tsss", group 13 of 100
# getting wall of "k46", group 14 of 100
# getting wall of "podslushano_volhov", group 15 of 100
# getting wall of "pavlovo4u", group 16 of 100
# getting wall of "publicpodsluwanokalmykiya", group 17 of 100
# getting wall of "podslushano_kop", group 18 of 100
# getting wall of "overhear_volzsk", group 19 of 100
# ...

# %%
corpora = mining.to_corpora(group_data)
with open('corpora.json', 'w') as f:
    json.dump(corpora, f)
# Out:
# processing "overhear", group 0 of 100
# processing "podslushanoklubromantiki", group 1 of 100
# processing "secret_32", group 2 of 100
# processing "podslushanoperm", group 3 of 100
# processing "overstory163", group 4 of 100
# processing "yarchat", group 5 of 100
# processing "podslushanokovrov1", group 6 of 100
# processing "in_yalta", group 7 of 100
# processing "sluhvl", group 8 of 100
# processing "buzpb", group 9 of 100
# processing "ovhdzr", group 10 of 100
# processing "beloretsk3", group 11 of 100
# processing "showvk", group 12 of 100
# processing "pravda.show.tsss", group 13 of 100
# processing "k46", group 14 of 100
# processing "podslushano_volhov", group 15 of 100
# processing "pavlovo4u", group 16 of 100
# processing "publicpodsluwanokalmykiya", group 17 of 100
# processing "podslushano_kop", group 18 of 100
# processing "overhear_volzsk", group 19 of 100
# processing "podnsk", group 20 of 100
# processing "yumorxxl", group 21 of 100
# ...

# %%
corpora_frame = statistics.to_stat_frame(corpora)
corpora_frame
# Out:
#                         group  memb_count  \
# 0                  Подслушано     3990568
# 1   Подслушано клуб романтики      194237
# 2           Подслушано Брянск      174501
# 3            ПОДСЛУШАНО ПЕРМЬ      428410
# 4         Подслушано | Самара      296562
# ..                        ...         ...
# 95   Подслушано: Горнозаводск       22114
# 96         Подслушано Гагарин       25786
# 97       Подслушано l Иваново      113775
# 98               Orto Blogge.       96601
# 99             ИНДУЛЬГЕНЦИЯ †     2450799
#
#                                           description  words_per_post  \
# 0   Мы публикуем только то, что присылают наши чит...           77.21
# 1   Все рубрике смотрите по этим хэштегам :\n#сцен...           73.59
# 2                      🔺Online | «Подслушано» Брянска           30.80
# 3   Подслушано Пермь - это откровения пермяков на ...           78.19
# 4   Самое популярное информационно-развлекательное...           75.89
# ...
