# %%
import json
import pandas as pd
import utils.mining as mining
import utils.stats as stats
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/zhestyatsky/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/zhestyatsky/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/zhestyatsky/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
# Downloading data from VK
# !python3 utils/load_data.py --login YOUR_LOGIN --password YOUR_PASSWORD

# %%
with open('data/group_data.json', 'r') as gr_data_file:
    group_data = json.load(gr_data_file)

# %%
corpora = mining.to_corpora(group_data)
with open('data/corpora.json', 'w') as corpora_file:
    json.dump(corpora, corpora_file)
# Out:
# processing "overhear", group 0 of 100
# processing "podslushanoklubromantiki", group 1 of 100
# processing "secret_32", group 2 of 100
# processing "podslushanoperm", group 3 of 100
# processing "overstory163", group 4 of 100
# processing "yarchat", group 5 of 100
# processing "podslushanokovrov1", group 6 of 100
# processing "in_yalta", group 7 of 100
# processing "sluhvl", group 8 of 100
# processing "buzpb", group 9 of 100
# processing "ovhdzr", group 10 of 100
# processing "beloretsk3", group 11 of 100
# processing "showvk", group 12 of 100
# processing "pravda.show.tsss", group 13 of 100
# processing "k46", group 14 of 100
# processing "podslushano_volhov", group 15 of 100
# processing "pavlovo4u", group 16 of 100
# processing "publicpodsluwanokalmykiya", group 17 of 100
# processing "podslushano_kop", group 18 of 100
# processing "overhear_volzsk", group 19 of 100
# processing "podnsk", group 20 of 100
# processing "yumorxxl", group 21 of 100
# ...

# %%
corpora_frame = stats.to_stat_frame(corpora)
corpora_frame
# Out:
#                         group  memb_count  \
# 0                  Подслушано     3990577
# 1   Подслушано клуб романтики      194257
# 2           Подслушано Брянск      174505
# 3            ПОДСЛУШАНО ПЕРМЬ      428409
# 4         Подслушано | Самара      296564
# ..                        ...         ...
# 95   Подслушано: Горнозаводск       22114
# 96         Подслушано Гагарин       25786
# 97       Подслушано l Иваново      113778
# 98               Orto Blogge.       96602
# 99             ИНДУЛЬГЕНЦИЯ †     2450801
#
#                                           description  words_per_post  \
# 0   Мы публикуем только то, что присылают наши чит...           77.80
# 1   Все рубрике смотрите по этим хэштегам :\n#сцен...           73.59
# 2                      🔺Online | «Подслушано» Брянска           31.25
# 3   Подслушано Пермь - это откровения пермяков на ...           77.51
# 4   Самое популярное информационно-развлекательное...           74.25
# ...
